# %% [markdown]
# # 03-05
#
# # Challenge 05 - Republicans vs Democrats
# ![](https://images.unsplash.com/photo-1540908390241-82158ab62887?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1350&q=80)
# Picture by [Element5 Digital](https://unsplash.com/photos/ls8Kc0P9hAA)

# %% [markdown]
# Now let's talk about categorical variables correlations. We want to know whether gender has an impact on political opinions. To do that, we will use the dataset  `repsOrDems.csv`.

# %%
# TODO: import libraries, load the file repsOrDems.csv and check it out
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

repo = pd.read_csv('repsOrDems.csv')
repo.isnull().sum()
repo.describe()
#repo = repo.drop_duplicates()
repo
# Out:
#      gender       voting
# 0    female    democrats
# 1    female  republicans
# 2      male  republicans
# 3    female  republicans
# 4      male  independent
# 5    female    democrats
# 6      male  independent
# 7    female  republicans
# 8      male  republicans
# 9    female  republicans
# 10   female    democrats
# 11   female  republicans
# 12   female  republicans
# 13   female  republicans
# 14     male  republicans
# 15   female  republicans
# 16     male  independent
# 17   female    democrats
# 18   female  independent
# 19   female    democrats
# 20   female  republicans
# 21   female  republicans
# 22   female    democrats
# 23   female  republicans
# 24   female  republicans
# 25     male    democrats
# 26     male  republicans
# 27     male    democrats
# 28     male    democrats
# 29   female  republicans
# ..      ...          ...
# 970  female    democrats
# 971  female  republicans
# 972    male  republicans
# 973    male  independent
# 974    male  independent
# 975    male    democrats
# 976  female  republicans
# 977  female  republicans
# 978    male  republicans
# 979  female  independent
# 980  female  republicans
# 981  female  independent
# 982    male    democrats
# 983    male    democrats
# 984  female    democrats
# 985  female  republicans
# 986    male    democrats
# 987  female  independent
# 988  female  republicans
# 989  female  republicans
# 990    male    democrats
# 991  female    democrats
# 992  female  republicans
# 993    male  independent
# 994    male  republicans
# 995    male    democrats
# 996  female    democrats
# 997  female    democrats
# 998  female  republicans
# 999  female  republicans
#
# [1000 rows x 2 columns]

# %% [markdown]
# Now we will want to compute the correlation between gender and voting. To do that, you first have to make the contigency table, like in the courses.
#
# Hint: you can use the *crosstab* function of pandas (go check on the internet for more details).

# %%
# TODO: use pandas.crosstab to compute the contingency table
gender_voting  = pd.crosstab(index = repo['gender'], columns = repo['voting'])


gender_voting
# Out:
# voting  democrats  independent  republicans
# gender
# female        300           50          250
# male          150           50          200

# %% [markdown]
# Then using *scipy*, compute the $\chi^2$ correlation, and print the p-value.

# %%
# TODO: compute the chi square and print the p-value
import scipy.stats as stats


# Compute the chi square and the p-value and print them
chi2, p, dof, expected = stats.chi2_contingency(gender_voting)
print('chi square:', chi2)
print('p-value:', p)
# Out:
# chi square: 16.203703703703702
# p-value: 0.0003029775487145488

# %% [markdown]
# What p-value do you find?
#
# More important, is there a correlation between gender and voting?

# %% [markdown]
# If you still have time, try to compute by hand the $\chi^2$ and find the right value.
